# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt('chain_progress_2500.txt')

# %%
for i in range(1, 7):
    plt.plot(data[:,i][:2500])
    plt.show()
    plt.loglog(np.abs(np.fft.rfft(data[:,i][:2500])))
    plt.show()
